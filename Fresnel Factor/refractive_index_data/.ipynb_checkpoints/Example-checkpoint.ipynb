# %%
import numpy as np
from refractive_indices import n_sapphire, n_gold, n_water

# %%
omega = np.linspace(2500,4000,10000)

# %%
from matplotlib import pyplot as plt

# %%
ns,ks = n_sapphire(omega)
ng,kg = n_gold(omega)
nw,kw = n_water(omega)

# %%
plt.plot(omega,ns,omega,ks)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd6a95d8160>,
#  <matplotlib.lines.Line2D at 0x7fd6a95d8190>]

# %%
plt.plot(omega,ng,omega,kg)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd6a98c4e50>,
#  <matplotlib.lines.Line2D at 0x7fd6a98c4e80>]

# %%
plt.plot(omega,nw,omega,kw)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd6a9a0f580>,
#  <matplotlib.lines.Line2D at 0x7fd6a9a0f5b0>]
